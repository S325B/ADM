# %% [markdown]
# <a href="https://colab.research.google.com/github/S325B/ADM/blob/main/LP3_PCW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Implementing a Perceptron

# %% [markdown]
# Your task in this workbook is to implement a Perceptron model, train it and evaluate it. Step-by-step tasks are defined below.

# %% [markdown]
# ## 1) Import Libraries

# %% [markdown]
# - Add new import lines to the cell below

# %%
from sklearn.datasets import load_breast_cancer # Data will be loaded from this library

# %% [markdown]
# ## 2) Load Data

# %% [markdown]
# - Below, load the data using the load_breast_cancer() function imported above
# - Split the data into train and test keeping a randomly selected 20% of the data for test

# %%
# Load the Breast Cancer dataset here

# Print few data samples

# %% [markdown]
# *   Shortly explain the dataset: what are the labels/target-variable? Which categories are available? Which features are available? (Keep your answer brief, about a paragraph of 5-6 sentences max.)

# %%
# Split the dataset

# Print data shapes
print("Training data shape:", X_train.shape)
print("Training labels shape:", y_train.shape)
print("Test data shape:", X_test.shape)
print("Test labels shape:", y_test.shape)

# %% [markdown]
# ## 3) Implementing the Perceptron

# %% [markdown]
# - In this section, you are expected to define a Perceptron class. In the class definition, **weights** should be assigned randomly, **alpha** (learning rate) should be used as a parameter and a default value should be assigned, and **forward**, **update** and **training** functions should be implemented **(training can be written outside the perceptron class according to personal preferences.)**
#
# - Create a Perceptron object and train it using the data defined above.

# %%
# Write your code here

# %% [markdown]
# ## 4) Compute Accuracy

# %% [markdown]
# - Complete the implementation of the compute_accuracy() function below
# - Use the function you defined to evaluate your trained model on the test data

# %%
def compute_accuracy(model, X_inputs, y_outputs):

    "...."

    return accuracy

# %% [markdown]
# ## 5) Confusion Matrix

# %% [markdown]
# - Write code to create and print/plot the confusion matrix

# %%
# Write your code here

# %% [markdown]
# **Answer the following questions:**
#
# **In this part, you are asked to interpret the results above (i.e. your own results), not only provide general descriptions on how the metrics are computed, or a random examplary confusion matrix. You should use numbers (explicitly numerical, not using variable names) from your own confusion matrix in answering the first three question.**
#
# 1.   How many subjects had cancer and wrongly predicted to have no cancer?
# 2.   Explain what 'false positive' refers to. What is the false positive rate of your model on this test dataset?
# 3.   What is the recall rate for detecting subjects with cancer?
# 4.   Among various classification measures, pick 2-best to be used in this problem for evaluation of the model.
